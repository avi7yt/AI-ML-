# %%
# Declaring and initializing the variables in python
# In Python, declaration and initialization happen simultaneously the moment you first assign a value to a variable using the = operator. Unlike languages like Java or C++, Python has no dedicated command or keyword to declare a variable before assigning its value.

x = 5
print(type(x))
user_name = "Alice"

x = "hello"

print(x)

# Advanced Assignment Shortcuts
# Many values to many variables:
a,b,c = "Apple", "Banana", "Cherry"
print(a,b,c)

# Swapping two variables directly
a, b = b, a
print(a,b)
# Out:
# <class 'int'>
# hello
# Apple Banana Cherry
# Banana Apple

# %%
# Four types of datatypes in python: int, float, string, boolean

#1 Set price = 250 and quantity = 3. Print the total cost.
price, quanitity = 250, 3
print("Total cost is: ", price*quanitity)

#2 Use % to check if 91 is even or odd
digit = 10
if digit % 2 == 0:
    print(digit, "is even")
else:
    print(digit, " is odd")

#3 A student passes, if marks >= 40 and attendance >= 75. Set values and print True/False.
marks, attendance = 33, 46
if marks >= 40 and attendance >= 75:
    print("Congratulations you are passed")
else:
    print("Sorry you are not passed")

#4 Check whether "Chemistry" is the subject list above
Subjects = ["Mathematics", "Advanced Data Structure", "Data Visualization using Python", "Frontend Software Development", "Chemistry"]
# Out:
# Total cost is:  750
# 10 is even
# Sorry you are not passed
