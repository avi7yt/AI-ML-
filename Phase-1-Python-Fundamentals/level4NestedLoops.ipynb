# %%
'''
print this-> 
*
**
***
****
*****
'''
x = 1
for i in range(5): 
    for j in range(x):
        print("*", end=" ")
    x += 1

    print("")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
# String in python 
name = "Akash"
lastname = "  Vishwakarma   "
fruit = "apple,banana,mango"
print(f"characters in name: {len(name)}")
print(f"In uppercase: {name.upper()}")
print(f"In lowercase: {name.lower()}")
print(f"Removes whitespaces: {lastname.strip()}")
print(f"Replace lastname as {lastname} to {lastname.replace("a","x")}")
fruitarr = fruit.split()
print(fruitarr)
print(f"is A is in name : {"a" in name}")
for i in name:
    print(i, end=" ")
# Out:
# characters in name: 5
# In uppercase: AKASH
# In lowercase: akash
# Removes whitespaces: Vishwakarma
# Replace lastname as   Vishwakarma    to   Vishwxkxrmx
# ['apple,banana,mango']
# is A is in name : True
# A k a s h

# %%
# String methods
fileName = input("Enter you file here: ")
if(not fileName.endswith(".html")): 
    print("please upload .html file")
else: 
    print("Thankyou for you contribution")
# Out:
# Thankyou for you contribution
