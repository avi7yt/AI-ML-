# %%
# Core structure(if, elif, else)

age = int(input("Enter age: "))
if age > 18: print("You are eligible")
else: print("Not eligible")

marks = int(input("Enter marks: "))
if marks >= 90 and marks <= 100: print("Grade: A")
elif marks >= 80 and marks < 90: print("Grade: B")
elif marks >= 70 and marks <= 80: print("Grade: C")
elif marks >= 60 and marks <= 70: print("Grade: D")
else: print("Fail")
# Out:
# You are eligible
# Grade: A

# %%
# Advanced Conditional Syntax 
# 1. Ternery Operator(One-line)
a = 10
b = 20
print("a is greater than b") if a > b else print("b is greater than a")
# Out:
# b is greater than a
